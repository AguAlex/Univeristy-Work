# %%
import numpy as np

# a
images = []
for i in range(9):
    image = np.load(f"images/car_{i}.npy")
    images.append(image)

images = np.array(images)

# b
# suma = 0
# for arr in images:
#     suma += np.sum(arr)

#print(suma)
# c
sume = []
for arr in images:
    sume.append(np.sum(arr))

sume = np.array(sume)
print(sume)
# Out:
# [28685144 39333369 26884392 33514492 29317095 35118308 22727807 32168248
#  22033563]

# %%
# d
suma_maxima = max(sume)


for i in range(len(sume)):
    if sume[i] == suma_maxima:
        print(i)
        break
# Out:
# 1

# %%
# e
from skimage import io
suma_imagini = np.zeros((400,600))
for img in images:
    suma_imagini += img

mean_image = suma_imagini / 9

io.imshow(mean_image.astype(np.uint8)) # petru a putea fi afisata
 # imaginea trebuie sa aiba
 # tipul unsigned int
io.show()
# Out:
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\2903304144.py:9: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(mean_image.astype(np.uint8)) # petru a putea fi afisata
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\2903304144.py:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
# f
print(np.std(images))
# Out:
# 69.49910028574715

# %%
# g
img_normalizare = []

for img in images:
    arr = (img - mean_image) / np.std(images)
    img_normalizare.append(arr)

img_normalizare = np.array(img_normalizare)

io.imshow(img_normalizare[0].astype(np.uint8)) # petru a putea fi afisata
 # imaginea trebuie sa aiba
 # tipul unsigned int
io.show()
# Out:
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\4060652571.py:10: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_normalizare[0].astype(np.uint8)) # petru a putea fi afisata
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\4060652571.py:13: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
imagine_crop = images[1][200:301, 280:401]
io.imshow(imagine_crop.astype(np.uint8)) # petru a putea fi afisata
 # imaginea trebuie sa aiba
 # tipul unsigned int
io.show()
# Out:
# [[ 50  43  58 ...  67  59  60]
#  [ 59  64  61 ...  64  59  60]
#  [ 64  57  57 ...  70  64  60]
#  ...
#  [  4   4   4 ... 187 208 198]
#  [  4   4   4 ... 159 172 187]
#  [  4   4   4 ... 203 201 198]]
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\2055181701.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(imagine_crop.astype(np.uint8)) # petru a putea fi afisata
# C:\Users\Agu\AppData\Local\Temp\ipykernel_656\2055181701.py:6: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
